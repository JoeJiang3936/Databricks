# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <h3 class="alert-heading">Hi ! </h3>
#   <p>My name is Tom.</p>
#   <p>This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. DBFS is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# I have imported a file that is the raw diamonds dataset file as an example, and now I will query it.</p>
#   <hr>
#   <p class="mb-0">This notebook is about showing SparkSQL in action ! </p>
# </div>

# %% [markdown]
# <br>

# %%
# from IPython.core.display import display, HTML
from pyspark.sql.functions import avg
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <h4 class="alert-heading">Process</h4>
#   <p>I have uploaded a file called tom_diamonds_data.csv. I am going to now do SQL-like queries on it. </p>
# </div>

# %%
# File location and type
# When you import data into databricks, its defaults to put it into /Filestore/tables
file_location = "/FileStore/tables/tom_diamonds_data.csv"
file_type = "csv"  # my data is .csv diamonds dataset


# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","
# i am going to let it infer the schema ! 

# The applied options are for CSV files. For other file types, these will be ignored.
sdf = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

# lets look at it 
display(sdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th></tr></thead><tbody><tr><td>0.23</td><td>Ideal</td><td>E</td><td>SI2</td><td>61.5</td><td>55.0</td><td>326</td><td>3.95</td><td>3.98</td><td>2.43</td></tr><tr><td>0.21</td><td>Premium</td><td>E</td><td>SI1</td><td>59.8</td><td>61.0</td><td>326</td><td>3.89</td><td>3.84</td><td>2.31</td></tr><tr><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>56.9</td><td>65.0</td><td>327</td><td>4.05</td><td>4.07</td><td>2.31</td></tr><tr><td>0.29</td><td>Premium</td><td>I</td><td>VS2</td><td>62.4</td><td>58.0</td><td>334</td><td>4.2</td><td>4.23</td><td>2.63</td></tr><tr><td>0.31</td><td>Good</td><td>J</td><td>SI2</td><td>63.3</td><td>58.0</td><td>335</td><td>4.34</td><td>4.35</td><td>2.75</td></tr><tr><td>0.24</td><td>Very Good</td><td>J</td><td>VVS2</td><td>62.8</td><td>57.0</td><td>336</td><td>3.94</td><td>3.96</td><td>2.48</td></tr><tr><td>0.24</td><td>Very Good</td><td>I</td><td>VVS1</td><td>62.3</td><td>57.0</td><td>336</td><td>3.95</td><td>3.98</td><td>2.47</td></tr><tr><td>0.26</td><td>Very Good</td><td>H</td><td>SI1</td><td>61.9</td><td>55.0</td><td>337</td><td>4.07</td><td>4.11</td><td>2.53</td></tr><tr><td>0.22</td><td>Fair</td><td>E</td><td>VS2</td><td>65.1</td><td>61.0</td><td>337</td><td>3.87</td><td>3.78</td><td>2.49</td></tr><tr><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>59.4</td><td>61.0</td><td>338</td><td>4.0</td><td>4.05</td><td>2.39</td></tr><tr><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>64.0</td><td>55.0</td><td>339</td><td>4.25</td><td>4.28</td><td>2.73</td></tr><tr><td>0.23</td><td>Ideal</td><td>J</td><td>VS1</td><td>62.8</td><td>56.0</td><td>340</td><td>3.93</td><td>3.9</td><td>2.46</td></tr><tr><td>0.22</td><td>Premium</td><td>F</td><td>SI1</td><td>60.4</td><td>61.0</td><td>342</td><td>3.88</td><td>3.84</td><td>2.33</td></tr><tr><td>0.31</td><td>Ideal</td><td>J</td><td>SI2</td><td>62.2</td><td>54.0</td><td>344</td><td>4.35</td><td>4.37</td><td>2.71</td></tr><tr><td>0.2</td><td>Premium</td><td>E</td><td>SI2</td><td>60.2</td><td>62.0</td><td>345</td><td>3.79</td><td>3.75</td><td>2.27</td></tr><tr><td>0.32</td><td>Premium</td><td>E</td><td>I1</td><td>60.9</td><td>58.0</td><td>345</td><td>4.38</td><td>4.42</td><td>2.68</td></tr><tr><td>0.3</td><td>Ideal</td><td>I</td><td>SI2</td><td>62.0</td><td>54.0</td><td>348</td><td>4.31</td><td>4.34</td><td>2.68</td></tr><tr><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>63.4</td><td>54.0</td><td>351</td><td>4.23</td><td>4.29</td><td>2.7</td></tr><tr><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>63.8</td><td>56.0</td><td>351</td><td>4.23</td><td>4.26</td><td>2.71</td></tr><tr><td>0.3</td><td>Very Good</td><td>J</td><td>SI1</td><td>62.7</td><td>59.0</td><td>351</td><td>4.21</td><td>4.27</td><td>2.66</td></tr><tr><td>0.3</td><td>Good</td><td>I</td><td>SI2</td><td>63.3</td><td>56.0</td><td>351</td><td>4.26</td><td>4.3</td><td>2.71</td></tr><tr><td>0.23</td><td>Very Good</td><td>E</td><td>VS2</td><td>63.8</td><td>55.0</td><td>352</td><td>3.85</td><td>3.92</td><td>2.48</td></tr><tr><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>61.0</td><td>57.0</td><td>353</td><td>3.94</td><td>3.96</td><td>2.41</td></tr><tr><td>0.31</td><td>Very Good</td><td>J</td><td>SI1</td><td>59.4</td><td>62.0</td><td>353</td><td>4.39</td><td>4.43</td><td>2.62</td></tr><tr><td>0.31</td><td>Very Good</td><td>J</td><td>SI1</td><td>58.1</td><td>62.0</td><td>353</td><td>4.44</td><td>4.47</td><td>2.59</td></tr><tr><td>0.23</td><td>Very Good</td><td>G</td><td>VVS2</td><td>60.4</td><td>58.0</td><td>354</td><td>3.97</td><td>4.01</td><td>2.41</td></tr><tr><td>0.24</td><td>Premium</td><td>I</td><td>VS1</td><td>62.5</td><td>57.0</td><td>355</td><td>3.97</td><td>3.94</td><td>2.47</td></tr><tr><td>0.3</td><td>Very Good</td><td>J</td><td>VS2</td>< ...

# %% [markdown]
# <div class="alert alert-info">
#
# With this registered as a temp view, it will only be available to this particular notebook
#
# If you'd like other users to be able to query this table, you can also create a table from the DataFrame
#
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data. Let's do it.
#
# </div>

# %%
print(type(sdf))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pyspark.sql.dataframe.DataFrame&apos;&gt;
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>NOTE</b> This is a Spark Dataframe.  It is not a pandas dataframe.  I am within a Pyspark Instance here.
# </div>

# %%
# Create a view or table
# This is key 

temp_table_name = "tom_diamonds_data_csv"
sdf.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

/* Query the created temp table in a SQL cell, just like going home for dinner */

select * from `tom_diamonds_data_csv` LIMIT 10
/* show me the top ten rows of my data */
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th></tr></thead><tbody><tr><td>0.23</td><td>Ideal</td><td>E</td><td>SI2</td><td>61.5</td><td>55.0</td><td>326</td><td>3.95</td><td>3.98</td><td>2.43</td></tr><tr><td>0.21</td><td>Premium</td><td>E</td><td>SI1</td><td>59.8</td><td>61.0</td><td>326</td><td>3.89</td><td>3.84</td><td>2.31</td></tr><tr><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>56.9</td><td>65.0</td><td>327</td><td>4.05</td><td>4.07</td><td>2.31</td></tr><tr><td>0.29</td><td>Premium</td><td>I</td><td>VS2</td><td>62.4</td><td>58.0</td><td>334</td><td>4.2</td><td>4.23</td><td>2.63</td></tr><tr><td>0.31</td><td>Good</td><td>J</td><td>SI2</td><td>63.3</td><td>58.0</td><td>335</td><td>4.34</td><td>4.35</td><td>2.75</td></tr><tr><td>0.24</td><td>Very Good</td><td>J</td><td>VVS2</td><td>62.8</td><td>57.0</td><td>336</td><td>3.94</td><td>3.96</td><td>2.48</td></tr><tr><td>0.24</td><td>Very Good</td><td>I</td><td>VVS1</td><td>62.3</td><td>57.0</td><td>336</td><td>3.95</td><td>3.98</td><td>2.47</td></tr><tr><td>0.26</td><td>Very Good</td><td>H</td><td>SI1</td><td>61.9</td><td>55.0</td><td>337</td><td>4.07</td><td>4.11</td><td>2.53</td></tr><tr><td>0.22</td><td>Fair</td><td>E</td><td>VS2</td><td>65.1</td><td>61.0</td><td>337</td><td>3.87</td><td>3.78</td><td>2.49</td></tr><tr><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>59.4</td><td>61.0</td><td>338</td><td>4.0</td><td>4.05</td><td>2.39</td></tr></tbody></table></div>

# %%
# %sql

/* SELECT the column 'cut' */

select cut from `tom_diamonds_data_csv` LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cut</th></tr></thead><tbody><tr><td>Ideal</td></tr><tr><td>Premium</td></tr><tr><td>Good</td></tr><tr><td>Premium</td></tr><tr><td>Good</td></tr><tr><td>Very Good</td></tr><tr><td>Very Good</td></tr><tr><td>Very Good</td></tr><tr><td>Fair</td></tr><tr><td>Very Good</td></tr></tbody></table></div>

# %%
# %sql
SELECT * from tom_diamonds_data_csv WHERE cut='Very Good' LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th></tr></thead><tbody><tr><td>0.24</td><td>Very Good</td><td>J</td><td>VVS2</td><td>62.8</td><td>57.0</td><td>336</td><td>3.94</td><td>3.96</td><td>2.48</td></tr><tr><td>0.24</td><td>Very Good</td><td>I</td><td>VVS1</td><td>62.3</td><td>57.0</td><td>336</td><td>3.95</td><td>3.98</td><td>2.47</td></tr><tr><td>0.26</td><td>Very Good</td><td>H</td><td>SI1</td><td>61.9</td><td>55.0</td><td>337</td><td>4.07</td><td>4.11</td><td>2.53</td></tr><tr><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>59.4</td><td>61.0</td><td>338</td><td>4.0</td><td>4.05</td><td>2.39</td></tr><tr><td>0.3</td><td>Very Good</td><td>J</td><td>SI1</td><td>62.7</td><td>59.0</td><td>351</td><td>4.21</td><td>4.27</td><td>2.66</td></tr></tbody></table></div>

# %%
# %sql
SELECT * from tom_diamonds_data_csv WHERE cut='Very Good' LIMIT 5

# %%
# %sql
/* Break out the count of each type of cut */ 
SELECT cut, COUNT(*) as cut_count from tom_diamonds_data_csv as cut_count GROUP BY cut
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cut</th><th>cut_count</th></tr></thead><tbody><tr><td>Premium</td><td>13791</td></tr><tr><td>Ideal</td><td>21551</td></tr><tr><td>Good</td><td>4906</td></tr><tr><td>Fair</td><td>1610</td></tr><tr><td>Very Good</td><td>12082</td></tr></tbody></table></div>

# %%
# %sql
SELECT cut, AVG(price) as avg_price from tom_diamonds_data_csv GROUP BY cut
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cut</th><th>avg_price</th></tr></thead><tbody><tr><td>Premium</td><td>4584.2577042999055</td></tr><tr><td>Ideal</td><td>3457.541970210199</td></tr><tr><td>Good</td><td>3928.864451691806</td></tr><tr><td>Fair</td><td>4358.757763975155</td></tr><tr><td>Very Good</td><td>3981.7598907465654</td></tr></tbody></table></div>

# %%
# %sql
SELECT cut, AVG(price) as avg_price from tom_diamonds_data_csv GROUP BY cut
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cut</th><th>avg_price</th></tr></thead><tbody><tr><td>Premium</td><td>4584.2577042999055</td></tr><tr><td>Ideal</td><td>3457.541970210199</td></tr><tr><td>Good</td><td>3928.864451691806</td></tr><tr><td>Fair</td><td>4358.757763975155</td></tr><tr><td>Very Good</td><td>3981.7598907465654</td></tr></tbody></table></div>

# %% [markdown]
# ```
# STANDARD SELECT TYPE COMMAND YOU CARE ABOUT:
#
#
# SELECT [hints, ...] [ALL|DISTINCT] named_expression[, named_expression, ...]
#   FROM relation[, relation, ...]
#   [lateral_view[, lateral_view, ...]]
#   [WHERE boolean_expression]
#   [aggregation [HAVING boolean_expression]]
#   [ORDER BY sort_expressions]
#   [CLUSTER BY expressions]
#   [DISTRIBUTE BY expressions]
#   [SORT BY sort_expressions]
#   [WINDOW named_window[, WINDOW named_window, ...]]
#   [LIMIT num_rows]
#
# named_expression:
#   : expression [AS alias]
#
# relation:
#   | join_relation
#   | (table_name|query|relation) [sample] [AS alias]
#   : VALUES (expressions)[, (expressions), ...]
#         [AS (column_name[, column_name, ...])]
#
# expressions:
#   : expression[, expression, ...]
#
# sort_expressions:
#   : expression [ASC|DESC][, expression [ASC|DESC], ...]```

# %%
permanent_table_name = "tom_diamonds_data_csv"
sdf.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# where is it ? 
display(dbutils.fs.ls("dbfs:/FileStore/tables"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/BreseeMSDS7330Unit11HW.docx</td><td>BreseeMSDS7330Unit11HW.docx</td><td>1807476</td></tr><tr><td>dbfs:/FileStore/tables/Cbp/</td><td>Cbp/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/README.md</td><td>README.md</td><td>2033</td></tr><tr><td>dbfs:/FileStore/tables/SMU/</td><td>SMU/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/beer_data.csv</td><td>beer_data.csv</td><td>3143</td></tr><tr><td>dbfs:/FileStore/tables/boston_train.csv</td><td>boston_train.csv</td><td>24462</td></tr><tr><td>dbfs:/FileStore/tables/iris.csv</td><td>iris.csv</td><td>3858</td></tr><tr><td>dbfs:/FileStore/tables/json.json</td><td>json.json</td><td>243</td></tr><tr><td>dbfs:/FileStore/tables/mushrooms.csv</td><td>mushrooms.csv</td><td>382127</td></tr><tr><td>dbfs:/FileStore/tables/parquet.gif</td><td>parquet.gif</td><td>43589</td></tr><tr><td>dbfs:/FileStore/tables/pledge_of_allegiance.txt</td><td>pledge_of_allegiance.txt</td><td>174</td></tr><tr><td>dbfs:/FileStore/tables/raw_csv_diamonds.csv</td><td>raw_csv_diamonds.csv</td><td>2772143</td></tr><tr><td>dbfs:/FileStore/tables/tom_diamonds_data.csv</td><td>tom_diamonds_data.csv</td><td>2772143</td></tr><tr><td>dbfs:/FileStore/tables/userdata1.parquet</td><td>userdata1.parquet</td><td>113629</td></tr></tbody></table></div>
